# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %% [markdown]
# 請參考https://medium.com/coinmonks/multi-label-classification-blog-tags-prediction-using-nlp-b0b5ee6686fc

# %% [markdown]
# 資料來源:從網絡抓取數據

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 目標: 從 medium 抓取數據並識別給定的標籤並以OneHotEncoding格式從中獲取Data Frame，然後對哪個Blog帖子歸入哪個標籤進行分類。

# %% [markdown]
# 評估指標: 使用 accuracy_score 來評估模型訓練的成果
