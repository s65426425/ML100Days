# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.random(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 76.023
# The Mean absolute error is 7.582

# %% [raw]
# # 作業2：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 1. 你選的這組資料為何重要
# <Ans>可以在眾多的圖片中來辨識動物，可以節省不少時間整理
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# <Ans>提供者是Bianca Ferreira，在google搜索合適的圖片下載，再以YOLO格式標示圖像
# 3. 蒐集而來的資料型態為何
# <Ans>每組資料皆有圖片檔JPG以及文字檔txt，這些圖像具有不同的長寬比
# 4. 這組資料想解決的問題如何評估
# <Ans>用YOLO辨識動物，可以依據拍攝時間以及地點來分析該動物的生活習性與生活地區

# %% [markdown]
# # 作業3：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# <Ans>1.減少司機們的空車時間
#      2.優化司機間的分配工作，不要讓他們太過密集，導致搶生意的情況
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# <Ans>資料由司機會報乘客上車地點/時間，下車地點/時間所記錄，也可以藉由叫車系統蒐集，分析出乘客搭車的尖峰時段以及熱門地點。連假、重要節日或者天氣與特殊事件等，可能會影響蒐集的資料。
# 3. 蒐集而來的資料型態為何
# <Ans>大多是數值及圖表等結構化資料
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# <Ans>透過模組分析模擬乘客的上下車地點及時間來分配司機的路線，遇到假期或者天氣變化也要另外分析
